# %% [markdown]
# # Regression and Other Stories: Chapter 2

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from bambi import Model
import arviz as az
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
# WAITING ON CLEANED DATA FROM AKI TO RECREATE HEALTH SPENDING VS LIFE EXPECTANCY

data = "https://raw.githubusercontent.com/avehtari/ROS-Examples/master/HealthExpenditure/data/healthexpenditure.csv"
health = pd.read_csv(data, skiprows=3, encoding = "ISO-8859-1")

# %%
data = "https://raw.githubusercontent.com/avehtari/ROS-Examples/master/HDI/data/hdi.dat"
health = pd.read_fwf(data, engine="python",)
health
# Out:
#          rank state hdi canada.dist
# 0        1 \t"Connecticut" \t.962 2
# 1      2 \t"Massachusetts" \t.961 2
# 2         3 \t"New Jersey" \t.961 2
# 3   4 \t"Washington, D.C." \t.960 4
# 4           5 \t"Maryland" \t.960 3
# 5             6 \t"Hawaii" \t.959 2
# 6           7 \t"New York" \t.959 1
# 7      8 \t"New Hampshire" \t.958 1
# 8          9 \t"Minnesota" \t.958 1
# 9      10 \t"Rhode Island" \t.958 3
# 10       11 \t"California" \t.958 3
# 11         12 \t"Colorado" \t.958 3
# 12         13 \t"Virginia" \t.957 4
# 13         14 \t"Illinois" \t.957 3
# 14          15 \t"Vermont" \t.955 1
# 15       16 \t"Washington" \t.955 1
# 16           17 \t"Alaska" \t.955 1
# 17         18 \t"Delaware" \t.953 4
# 18        19 \t"Wisconsin" \t.952 2
# 19         20 \t"Michigan" \t.951 1
# 20             21 \t"Iowa" \t.950 2
# 21     22 \t"Pennsylvania" \t.950 2
# 22         23 \t"Nebraska" \t.946 3
# 23           24 \t"Kansas" \t.941 4
# 24          25 \t"Arizona" \t.939 3
# ...
